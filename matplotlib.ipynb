# %%
import pandas as pd

import matplotlib.pyplot as plt

dataframe = pd.read_csv('heart_data.csv')
dataframe.head()
# Out:
#    rest_bp  chest_pain  thalassemia  age  fasting_bs  max_hr  exercise_angina  \
# 0      106           3            0   67           0     142                0
# 1      120           2            0   50           0     158                0
# 2      126           3            2   35           0     156                1
# 3      150           3            2   63           0     154                0
# 4      140           3            2   46           0     120                1
#
#    gender  st_slope  cholesterol  st_depression  rest_ecg  num_vessels  \
# 0       0         0          223            0.3         0            2
# 1       0         1          219            1.6         0            0
# 2       1         0          282            0.0         2            0
# 3       0         1          407            4.0         2            3
# 4       1         1          311            1.8         0            2
#
#    diagnosis
# 0          0
# 1          0
# 2          1
# ...

# %%
bp=dataframe['rest_bp']
chest_pain=dataframe['chest_pain']
age=dataframe['age']
plt.scatter(bp,age)

# %%
clostream=dataframe['cholesterol']
depresstion=dataframe['st_depression']

dataframe.plot(kind='scatter',x='age',y='rest_bp',color='#3c6290',marker='*')
# Out:
# <Axes: xlabel='age', ylabel='rest_bp'>

# %%
maxhours=dataframe['max_hr']
plt.plot(bp,linewidth=2)

# %%
x=["C++","Python","Java","Perl","Scala","Lisp","R"]
y=[10,8,6,4,2,1,7]

plt.bar(x,y,color='#2ECC71',width=0.5,edgecolor="#39F9ED",linewidth=9)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.boxplot(maxhours,showmeans=True,meanline=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc801484310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc801483190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc801483390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc801487ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc80148d850>],
#  'means': [<matplotlib.lines.Line2D at 0x7fc80148c9d0>]}

# %%
yesrs=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
salary=[10000,20000,30000,40000,50000,60000,70000,80000,90000,100000]


plt.plot(yesrs,salary,marker='o',color='g',linestyle='--',linewidth=2,markersize=10)
